# %%
itz = [{'period': '19.03년', 'eps_connect_list': 5352.0, 'eps_individual_list': 1473.0, 'per_list': 16.79, 'bps_list': 245447.0, 'pbr_list': 0.37, 'dps_list': 4000.0, 'dy_list': 3.4, 'roe_list': 2.22, 'net_margin_list': 1.56, 'op_margin_list': -0.14, 'stock_price_list': 118500.0}, {'period': '18.12년', 'eps_connect_list': 14127.0, 'eps_individual_list': 8937.0, 'per_list': 8.52, 'bps_list': 242062.0, 'pbr_list': 0.5, 'dps_list': 4000.0, 'dy_list': 2.6, 'roe_list': 5.84, 'net_margin_list': 4.18, 'op_margin_list': 5.2, 'stock_price_list': 156000.0}, {'period': '17.12년', 'eps_connect_list': 18938.0, 'eps_individual_list': 14368.0, 'per_list': 5.95, 'bps_list': 235358.0, 'pbr_list': 0.48, 'dps_list': 4000.0, 'dy_list': 2.7, 'roe_list': 8.05, 'net_margin_list': 5.77, 'op_margin_list': 6.47, 'stock_price_list': 146000.0}, {'period': '16.12년', 'eps_connect_list': 22479.0, 'eps_individual_list': 19040.0, 'per_list': 5.11, 'bps_list': 217263.0, 'pbr_list': 0.53, 'dps_list': 4000.0, 'dy_list': 2.7, 'roe_list': 10.35, 'net_margin_list': 6.98, 'op_margin_list': 9.6, 'stock_price_list': 149000.0}, {'period': '15.12년', 'eps_connect_list': 25735.0, 'eps_individual_list': 17212.0, 'per_list': 5.07, 'bps_list': 201958.0, 'pbr_list': 0.65, 'dps_list': 3000.0, 'dy_list': 1.8, 'roe_list': 12.74, 'net_margin_list': 8.23, 'op_margin_list': 8.68, 'stock_price_list': 169000.0}, {'period': '14.12년', 'eps_connect_list': 29921.0, 'eps_individual_list': 18150.0, 'per_list': 6.1, 'bps_list': 181909.0, 'pbr_list': 1.0, 'dps_list': 1950.0, 'dy_list': 0.8, 'roe_list': 16.45, 'net_margin_list': 9.78, 'op_margin_list': 8.93, 'stock_price_list': 236500.0}, {'period': '13.12년', 'eps_connect_list': 30008.0, 'eps_individual_list': 18494.0, 'per_list': 5.62, 'bps_list': 154264.0, 'pbr_list': 1.09, 'dps_list': 1900.0, 'dy_list': 0.9, 'roe_list': 19.45, 'net_margin_list': 10.14, 'op_margin_list': 9.97, 'stock_price_list': 218500.0}, {'period': '12.12년', 'eps_connect_list': 26818.0, 'eps_individual_list': 16607.0, 'per_list': 6.13, 'bps_list': 130003.0, 'pbr_list': 1.26, 'dps_list': 1750.0, 'dy_list': 0.8, 'roe_list': 20.63, 'net_margin_list': 9.84, 'op_margin_list': 10.95, 'stock_price_list': 213000.0}, {'period': '11.12년', 'eps_connect_list': 19060.0, 'eps_individual_list': 18450.0, 'per_list': 7.02, 'bps_list': 95508.0, 'pbr_list': 1.4, 'dps_list': 1500.0, 'dy_list': 0.9, 'roe_list': 19.96, 'net_margin_list': 4.83, 'op_margin_list': 8.78, 'stock_price_list': 173500.0}, {'period': '10.12년', 'eps_connect_list': 10416.0, 'eps_individual_list': 10374.0, 'per_list': 8.96, 'bps_list': 75880.0, 'pbr_list': 1.23, 'dps_list': 1150.0, 'dy_list': 1.0, 'roe_list': 13.73, 'net_margin_list': 3.25, 'op_margin_list': 7.02, 'stock_price_list': 121000.0}, {'period': '09.12년', 'eps_connect_list': 3008.0, 'eps_individual_list': 5078.0, 'per_list': 0, 'bps_list': 66799.0, 'pbr_list': 0, 'dps_list': 850.0, 'dy_list': 2.2, 'roe_list': 4.5, 'net_margin_list': 1.08, 'op_margin_list': 5.83, 'stock_price_list': 39500.0}, {'period': '08.12년', 'eps_connect_list': 2995.0, 'eps_individual_list': 2870.0, 'per_list': 0, 'bps_list': 246211.0, 'pbr_list': 0.37, 'dps_list': 0, 'dy_list': 0, 'roe_list': 0, 'net_margin_list': 3.46, 'op_margin_list': 2.09, 'stock_price_list': 119500.0}]

# %%
import pandas as pd
dfs = pd.DataFrame(itz)

# %%
dfs
# Out:
#     bps_list  dps_list  dy_list  eps_connect_list  eps_individual_list  \
# 0   245447.0    4000.0      3.4            5352.0               1473.0
# 1   242062.0    4000.0      2.6           14127.0               8937.0
# 2   235358.0    4000.0      2.7           18938.0              14368.0
# 3   217263.0    4000.0      2.7           22479.0              19040.0
# 4   201958.0    3000.0      1.8           25735.0              17212.0
# 5   181909.0    1950.0      0.8           29921.0              18150.0
# 6   154264.0    1900.0      0.9           30008.0              18494.0
# 7   130003.0    1750.0      0.8           26818.0              16607.0
# 8    95508.0    1500.0      0.9           19060.0              18450.0
# 9    75880.0    1150.0      1.0           10416.0              10374.0
# 10   66799.0     850.0      2.2            3008.0               5078.0
# 11  246211.0       0.0      0.0            2995.0               2870.0
#
# ...

# %%
temp = dfs
temp.set_index('period')
# Out:
#     period  bps_list  dps_list  dy_list  eps_connect_list  \
# 0   19.03년  245447.0    4000.0      3.4            5352.0
# 1   18.12년  242062.0    4000.0      2.6           14127.0
# 2   17.12년  235358.0    4000.0      2.7           18938.0
# 3   16.12년  217263.0    4000.0      2.7           22479.0
# 4   15.12년  201958.0    3000.0      1.8           25735.0
# 5   14.12년  181909.0    1950.0      0.8           29921.0
# 6   13.12년  154264.0    1900.0      0.9           30008.0
# 7   12.12년  130003.0    1750.0      0.8           26818.0
# 8   11.12년   95508.0    1500.0      0.9           19060.0
# 9   10.12년   75880.0    1150.0      1.0           10416.0
# 10  09.12년   66799.0     850.0      2.2            3008.0
# 11  08.12년  246211.0       0.0      0.0            2995.0
#
#     eps_individual_list  net_margin_list  op_margin_list  pbr_list  per_list  \
# 0                1473.0             1.56           -0.14      0.37     16.79
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
period = []
roe = []
pbr = []
roe = []
for idx in range(len(itz)):
    period.append(itz[idx]['period'])
    roe.append(itz[idx]['roe_list'])
    pbr.append(itz[idx]['pbr_list'])

pyplot.plot(roe, pbr, color = 'Green', marker="o")
for a, b, c in zip(roe, pbr, period): 
    pyplot.text(a, b, str(c))
    pyplot.quiver

pyplot.show()

# %%
plt.plot(roe, pbr, color="green", marker="o", ms=15, mec="g", mew=5, mfc="r")
